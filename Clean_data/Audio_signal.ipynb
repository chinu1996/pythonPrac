# %%
cd PycharmProjects
# Out:
# /home/das/PycharmProjects

# %%
import matplotlib.pyplot as plt
from scipy.io.wavfile import read
import numpy as np

# %%
(fs, x) = read('flute-A4.wav')
x.size/float(fs)
plt.plot(x)
plt.show()

# %%
t=np.arange(x.size)/float(fs)
plt.plot(t,x)
plt.show()

# %%
3+4
